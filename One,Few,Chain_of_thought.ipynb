# %% [markdown]
# One Short

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
generator = pipeline('translation', model='Helsinki-NLP/opus-mt-en-fr')
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu

# %%
prompt = "Hi my name is vipul"

# %%
print(generator(prompt))
# Out:
# [{'translation_text': 'Bonjour mon nom est vipul'}]

# %% [markdown]
# Few Short

# %%
from transformers import pipeline
generator = pipeline("translation",model="Helsinki-NLP/opus-mt-en-es")
prompt = """ Translate English to Spanish:
English:Good morning
Spanish:Buen día
English:Thank You
Spanish:       """
print(generator(prompt))
# Out:
# Device set to use cpu
# [{'translation_text': 'Traducir Inglés al Español: Inglés:Buenos días Español:Buen día Inglés:Gracias Español:'}]

# %% [markdown]
# Chain of Thought

# %%
from transformers import pipeline
cal = pipeline("text2text-generation",model="google/flan-t5-large")
prompt = "X has 10 apples, he gave 3 to y, how many apples are remaining? Answer only number"
print(cal(prompt))
# Out:
# Device set to use cpu
# [{'generated_text': '10 - 3 = 7 apples are remaining'}]
